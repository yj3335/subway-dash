# %% [markdown]
# # Subway Dash Data Profiling
#
# This notebook wraps the same profiling utilities used by `python -m processing.profile_data` so notebook results and CLI results stay consistent.

# %%
from pathlib import Path
from processing.config import RAW_STOPS, RAW_STATIONS, RAW_RIDERSHIP, RAW_WEATHER
from processing.profile_data import profile_csv, render_profiles, render_join_key_map

paths = [RAW_STOPS, RAW_STATIONS, RAW_RIDERSHIP, RAW_WEATHER]
profiles = [profile_csv(Path(path)) for path in paths]
print(render_profiles(profiles))

# %%
print(render_join_key_map(profiles[1], profiles[2], profiles[3]))
